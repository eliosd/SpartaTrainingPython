# %%
import pandas as pd

# %%
iris = pd.read_csv("iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['Rank'] = iris['petal_length'].rank()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species   Rank
# 0             5.1          3.5           1.4          0.2     setosa   17.5
# 1             4.9          3.0           1.4          0.2     setosa   17.5
# 2             4.7          3.2           1.3          0.2     setosa    8.0
# 3             4.6          3.1           1.5          0.2     setosa   30.5
# 4             5.0          3.6           1.4          0.2     setosa   17.5
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica  117.5
# 146           6.3          2.5           5.0          1.9  virginica  106.5
# 147           6.5          3.0           5.2          2.0  virginica  117.5
# 148           6.2          3.4           5.4          2.3  virginica  121.5
# 149           5.9          3.0           5.1          1.8  virginica  112.5
#
# [150 rows x 6 columns]

# %%
iris = iris.groupby('species')

# %%
iris

# %%
sepal = iris[['sepal_length', 'sepal_width', 'species']]
petal = iris[['petal_length', 'petal_width', 'species']]

# %%
petal.head()
# Out:
#      petal_length  petal_width     species
# 0             1.4          0.2      setosa
# 1             1.4          0.2      setosa
# 2             1.3          0.2      setosa
# 3             1.5          0.2      setosa
# 4             1.4          0.2      setosa
# 50            4.7          1.4  versicolor
# 51            4.5          1.5  versicolor
# 52            4.9          1.5  versicolor
# 53            4.0          1.3  versicolor
# 54            4.6          1.5  versicolor
# 100           6.0          2.5   virginica
# 101           5.1          1.9   virginica
# 102           5.9          2.1   virginica
# 103           5.6          1.8   virginica
# 104           5.8          2.2   virginica

# %% [markdown]
# # Merging

# %%
pd.merge(sepal, petal, how='inner', right_index=True, left_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 pd.merge(sepal, petal, how='inner', right_index=True, left_index=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:628, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     611 def __init__(
#     612     self,
#     613     left: DataFrame | Series,
#    (...)
#     626     validate: str | None = None,
#     627 ):
# --> 628     _left = _validate_operand(left)
#     629     _right = _validate_operand(right)
#     630     self.left = self.orig_left = _left
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:2281, in _validate_operand(obj)
#    2279         return obj.to_frame()
#    2280 else:
# -> 2281     raise TypeError(
#    2282         f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2283     )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'pandas.core.groupby.generic.DataFrameGroupBy'> was passed

# %%
pd.concat([versicolor, setosa], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 pd.concat([versicolor, setosa], axis=0)
#
# NameError: name 'versicolor' is not defined

# %%
import seaborn as sns

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pivot = flights.pivot('year', 'month', 'passengers')
flights_pivot
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights_pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
flights_stack = flights_pivot.stack()
flights_stack
# Out:
# year  month
# 1949  Jan      112
#       Feb      118
#       Mar      132
#       Apr      129
#       May      121
#               ...
# 1960  Aug      606
#       Sep      508
#       Oct      461
#       Nov      390
#       Dec      432
# Length: 144, dtype: int64

# %%
flights_stack[1955, 'Apr']
# Out:
# 269

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']
